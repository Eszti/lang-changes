# %% [markdown]
# # Data Preparation

# %%
# --------------------------------------------------------------------------------------------------------
# emigration.ipynb -- data preparation, inspection, and visualization 
# --------------------------------------------------------------------------------------------------------
# 0.01|02.01.22|AB|creation
# 0.02|03.01.22|AB|save result with pickle
# --------------------------------------------------------------------------------------------------------

# initialize

import numpy as np
import pandas as pd
#import glob
#import os
import matplotlib.pyplot as plt

#from datetime import datetime, date 
import re # regular expression
#import warnings
import pickle
import seaborn as sns

# %matplotlib inline
# %matplotlib notebook

PATH_DATA = r'../../data/'
INTERACTIVE = False
VALUE_COLNAME = 'nEmigrants'  # name for new column containing value of timeseries

if INTERACTIVE:
    # %matplotlib notebook
else:
    # %matplotlib inline

# %% [markdown]
# ## Emigration
#
# _Total number of long-term emigrants leaving from the reporting country during the reference year._
#
# - information about data availabilty
# https://ec.europa.eu/eurostat/web/main/data/database?p_p_id=NavTreeportletprod_WAR_NavTreeportletprod_INSTANCE_nPqeVbPXRmWQ&p_p_lifecycle=0&p_p_state=pop_up&p_p_mode=view&_NavTreeportletprod_WAR_NavTreeportletprod_INSTANCE_nPqeVbPXRmWQ_nodeInfoService=true&nodeId=-9012
#
# - meta data: N/A
# Last data update: 	13/03/2021 23:00
# Overall data coverage: 	2008 — 2019
# Source data set: https://ec.europa.eu/eurostat/databrowser/product/view/MIGR_IMM1CTZ
#
# for each EU country (35), #immigrants for 2008-2019
# special cases: ":" missing;
# two sets: agedef = COMPLET (age in completed years) and REACH (age reached during the year), resp.
#
# Missing values are indicated by a colon.
# Numbers may be accompanied by a 1- or 2-letter code with the following meaning:
#
# - b: break in time series
# - bp: break in time series, provisional
# - p: provisional
# - e: estimated
# - ep: estimated, provisional
#
# For the purpose of this study, this information is ignored and hence the characters removed, facilitating conversion of the data to numeric.
# - NO languages, no source country

# %%
fileName = PATH_DATA + 'tps00177.tsv'
# header = 1st line; missing value indicated by colon (followed by a space)
data = pd.read_csv(fileName, sep='\t', na_values=[': '], header=0)

# %%
data
# Out:
#    citizen,agedef,age,unit,sex,geo\time     2008     2009     2010     2011   \
# 0           TOTAL,COMPLET,TOTAL,NR,T,AT    51563    53244    51651    51197
# 1           TOTAL,COMPLET,TOTAL,NR,T,BE       NaN      NaN  66013 b  84148 b
# 2           TOTAL,COMPLET,TOTAL,NR,T,BG       NaN      NaN      NaN      NaN
# 3           TOTAL,COMPLET,TOTAL,NR,T,CH    86130    86036    96839   96494 b
# 4           TOTAL,COMPLET,TOTAL,NR,T,CY     4474    4797 b    4293     4895
# ..                                  ...       ...      ...      ...      ...
# 61            TOTAL,REACH,TOTAL,NR,T,RO  302796 b  246626   197985   195551
# 62            TOTAL,REACH,TOTAL,NR,T,SE    45294    39240    48853    51179
# 63            TOTAL,REACH,TOTAL,NR,T,SI   12109 b   18788    15937    12024
# 64            TOTAL,REACH,TOTAL,NR,T,SK     1705     1979     1889     1863
# 65            TOTAL,REACH,TOTAL,NR,T,UK  427207 b  368177   339306   350703
#
#        2012     2013     2014     2015     2016      2017      2018      2019
# 0     51812    54071    53491    56689    64428     66144     67212     68280
# 1     93600   102657    94573    89794    92471     89690     88935    102936
# 2   16615 bp  19678 p  28727 p  29470 p   30570    31586 p   33225 p   39941 p
# 3    103881   106196   111103   116631   120653    124997    130225    126221
# 4     18105    25227    24038    17183    14892     15105     15340     17373
# ..       ...      ...      ...      ...      ...       ...       ...       ...
# 61   170186   161755   172871   194718   207578   242193 e  231661 e  233736 e
# 62    51747    50715    51237    55830    45878     45620     46981     47718
# 63    14378    13384    14336    14913    15572     17555     13527     15106
# 64     2003     2770     3644     3870     3801      3466      3298      3384
# 65   321217   316934   319086   299183   340440    359665   344347 p   368385
#
# [66 rows x 13 columns]

# %% [markdown]
# First column defines content of time series.
# There are two sets: agedef = COMPLET (age in completed years) and REACH (age reached during the year), resp.
# In each group, there is a row for each country of the European Union (last two letters of 1st column).
# Since age is no criterion, the two sets are equal and only the first half of the dat is considered.

# %%
# remove duplicates and transform first column (keep only country code)

keepNRows = data.shape[0] // 2 # keep first half of table (68 -> 34)
data = data.iloc[0:keepNRows, ]

# keep last two characters (country code) -> new first column 'country'
data.insert(0, 'country', data.iloc[ : , 0].apply(lambda s: s[-2: ])) 
data
# Out:
#    country citizen,agedef,age,unit,sex,geo\time     2008      2009      2010   \
# 0       AT          TOTAL,COMPLET,TOTAL,NR,T,AT    51563     53244     51651
# 1       BE          TOTAL,COMPLET,TOTAL,NR,T,BE       NaN       NaN   66013 b
# 2       BG          TOTAL,COMPLET,TOTAL,NR,T,BG       NaN       NaN       NaN
# 3       CH          TOTAL,COMPLET,TOTAL,NR,T,CH    86130     86036     96839
# 4       CY          TOTAL,COMPLET,TOTAL,NR,T,CY     4474     4797 b     4293
# 5       CZ          TOTAL,COMPLET,TOTAL,NR,T,CZ   51478 b    61782     61069
# 6       DE          TOTAL,COMPLET,TOTAL,NR,T,DE   737889   286582 b   252456
# 7       DK          TOTAL,COMPLET,TOTAL,NR,T,DK   38356 b    39899     41456
# 8       EE          TOTAL,COMPLET,TOTAL,NR,T,EE     4406      4658      5294
# 9       EL          TOTAL,COMPLET,TOTAL,NR,T,EL   43044 b    43686    62041 b
# 10      ES          TOTAL,COMPLET,TOTAL,NR,T,ES  288432 b   380121    403377
# 11      FI          TOTAL,COMPLET,TOTAL,NR,T,FI    13657     12151     11905
# 12      FR          TOTAL,COMPLET,TOTAL,NR,T,FR   239796    264631   269531 b
# 13      HR          TOTAL,COMPLET,TOTAL,NR,T,HR   10638 b    12355     13017
# 14      HU          TOTAL,COMPLET,TOTAL,NR,T,HU    9591 b    10483    13365 b
# 15      IE          TOTAL,COMPLET,TOTAL,NR,T,IE    65934     69672     78099
# 16      IS          TOTAL,COMPLET,TOTAL,NR,T,IS     9144     6874 b     5459
# 17      IT          TOTAL,COMPLET,TOTAL,NR,T,IT    80947     80597     78771
# 18      LI          TOTAL,COMPLET,TOTAL,NR,T,LI     490 b      455       428
# 19      LT          TOTAL,COMPLET,TOTAL,NR,T,LT    25750     38500     83157
# 20      LU          TOTAL,COMPLET,TOTAL,NR,T,LU    10058      9168      9302
# 21      LV          TOTAL,COMPLET,TOTAL,NR,T,LV    27045     38208     39651
# 22      MK          TOTAL,COMPLET,TOTAL,NR,T,MK      751       792      1007
# 23      MT          TOTAL,COMPLET,TOTAL,NR,T,MT     3719      3868      4201
# 24      NL          TOTAL,COMPLET,TOTAL,NR,T,NL    90067    92825 b    95970
# 25      NO          TOTAL,COMPLET,TOTAL,NR,T,NO   12976 b    17072     25835
# 26      PL          TOTAL,COMPLET,TOTAL,NR,T,PL    30140   229320 b   218126
# 27      PT          TOTAL,COMPLET,TOTAL,NR,T,PT    20357     16899     23760
# 28      RO          TOTAL,COMPLET,TOTAL,NR,T,RO  302796 b   246626    197985
# 29      SE          TOTAL,COMPLET,TOTAL,NR,T,SE    45294     39240     48853
# 30      SI          TOTAL,COMPLET,TOTAL,NR,T,SI   12109 b    18788     15937
# 31      SK          TOTAL,COMPLET,TOTAL,NR,T,SK     1705      1979      1889
# 32      UK          TOTAL,COMPLET,TOTAL,NR,T,UK  427207 b   368177    339306
#
#       2011      2012     2013      2014      2015       2016       2017   \
# 0    51197     51812    54071     53491     56689      64428      66144
# 1   84148 b    93600   102657     94573     89794      92471      89690
# 2       NaN  16615 bp  19678 p   28727 p   29470 p     30570     31586 p
# 3   96494 b   103881   106196    111103    116631     120653     124997
# 4     4895     18105    25227     24038     17183      14892      15105
# 5   55910 b    46106   25894 b    28468     25684      38864      27316
# 6   249045    240001   259328   324221 e  338403 e  533762 be  560700 be
# 7    41593     43663    43310     44426     44625      52654      56403
# 8     6214      6321     6740      4637    13003 b     13792      12358
# 9    92404    124694   117094   106804 b   109351     106535     103327
# 10  409034    446606   532303    400430    343875     327325     368860
# 11   12660     13845    13893     15486     16305      18082      16973
# 12  291594    255922   239813    308103    324517     313622     215470
# 13   12699     12877    15262     20858     29651      36436      47352
# 14   15100     22880    34691     42213     43225      39889      39829
# 15  83049 b    81797    76560     71107     67160      62056      64068
# 16    4812      4758     4372      4052      4046       4159       3641
# 17   82461    106216   125735    136328    146955     157065     155110
# 18     467       439      497       476       468        522        426
# 19   53863     41100    38818     36621     44533      50333      47925
# 20    9264     10442    10750     11283     12644      13442      13831
# 21   30311     25163    22561     19017     20119      20574      17724
# 22    1290      1415     1041       839      1016        630        424
# 23    3806      4005     4778      5108      7095       8303       7020
# 24  104201    110431   112625    112900    112330     111477     108231
# 25   20349     22693    26523     29308     29173      34694      31963
# 26  265798    275603   276446   268299 p  258837 p  236441 ep  218492 ep
# 27   43998     51958    53786     49572     40377     38273 e    31753 e
# 28  195551    170186   161755    172871    194718     207578    242193 e
# 29   51179     51747    50715     51237     55830      45878      45620
# 30   12024     14378    13384     14336     14913      15572      17555
# 31    1863      2003     2770      3644      3870       3801       3466
# 32  350703    321217   316934    319086    299183     340440     359665
#
#         2018       2019
# 0      67212      68280
# 1      88935     102936
# 2     33225 p    39941 p
# 3     130225     126221
# 4      15340      17373
# 5      26742      77798
# 6    540415 e  576319 be
# 7      60381      66520
# 8      10476      12801
# 9     103049      95020
# 10    309526     296248
# 11     19141      17263
# 5     25684      38864      27316      26742      77798
# 6   338403 e  533762 be  560700 be   540415 e  576319 be
# 7     44625      52654      56403      60381      66520
# 8    13003 b     13792      12358      10476      12801
# 9    109351     106535     103327     103049      95020
# 10   343875     327325     368860     309526     296248
# 11    16305      18082      16973      19141      17263
# 12   324517     313622     215470    300668 p   299101 p
# 13    29651      36436      47352      39515      40148
# 14    43225      39889      39829      48178      49795
# 15    67160      62056      64068      53735      62004
# 16     4046       4159       3641       4372       4590
# 17   146955     157065     155110     156960     179505
# 18      468        522        426        484        446
# 19    44533      50333      47925      32206      29273
# 20    12644      13442      13831      13985      15593
# 21    20119      20574      17724      15814      14583
# 22     1016        630        424        377        798
# 23     7095       8303       7020       9342       7998
# 24   112330     111477     108231     109635     107906
# 25    29173      34694      31963      27158      23207
# 26  258837 p  236441 ep  218492 ep  189794 ep  180594 ep
# 27    40377     38273 e    31753 e     31600      28219
# 28   194718     207578    242193 e   231661 e   233736 e
# 29    55830      45878      45620      46981      47718
# 30    14913      15572      17555      13527      15106
# 31     3870       3801       3466       3298       3384
# 32   299183     340440     359665    344347 p    368385

# %% [markdown]
# Missing values are indicated by a colon.
# Numbers may be accompanied by a 1- or 2-letter code with the following meaning:
#
# - b: break in time series
# - bp: break in time series, provisional
# - p: provisional
# - e: estimated
# - ep: estimated, provisional
#
# For the purpose of this study, this information is ignored and hence the characters removed, facilitating conversion of the data to numeric.

# %%
# -- cleanse data
# data.replace("[a-z]+", "", regex=True, inplace=True) # warning (could be ignored)
data = data.replace("[a-z]+", "", regex=True, inplace=False) # alternative

# -- missing values
print("Count missing values per year:")
print(data.isna().sum())
# Out:
# Count missing values per year:
# country    0
# 2008       2
# 2009       2
# 2010       1
# 2011       1
# 2012       0
# 2013       0
# 2014       0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# 2019       0
# dtype: int64

# %%
data.dtypes # all object
# -> convert all year columns of DataFrame to numeric (and ignore errors caused by country)
data = data.apply(pd.to_numeric, errors='ignore')
# imputation: linear
data = data.interpolate(method = 'linear', limit_direction = 'both', axis = 0)

# %%
# year columns become attribute (pivoting wide to long -> melt())
# key is country (for each year and country, a row is to be created)
# use the year columns for the value column 
data = data.melt(['country'], value_vars = yearColumns, var_name = 'year', 
                                              value_name = VALUE_COLNAME)

# %%
# -- create an index
#immigrationData.set_index(['year', 'country'], inplace = True)
data.set_index(['year'], inplace = True)

# %%
# -- plot timeseries ----
sns.set()
# 1 plot per country:
# _ = immigrationData.groupby('country').plot(figsize = [14,20]) 
# all countries in 1 plot:
_ = data.groupby('country')[VALUE_COLNAME].plot(figsize = [12,14], legend=True)

# %%
# alternative: 1 col/country
_= data.pivot(columns='country', values=VALUE_COLNAME).plot(figsize = [12,14])

# %%
if False:
    data.reset_index(inplace=True)
    data

# %%
# save processed data
fileName = PATH_DATA + 'tps00177.pkl'
with open(fileName, 'wb') as outp:        
        pickle.dump(data, outp, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Citizenship
# 2008-2019 bzw. 2009-2020

# %%
"tps00024.tsv"
"tps00157.tsv"
# Out:
# 'tps00157.tsv'
