# %% [markdown]
# # Data Preparation

# %%
# --------------------------------------------------------------------------------------------------------
# immigration.ipynb -- data preparation, inspection, and visualization 
# --------------------------------------------------------------------------------------------------------
# 0.01|02.01.22|AB|creation
# 0.02|03.01.22|AB|save result with pickle
# 0.03|16.01.22|AB|save as csv, name and y-axis of diagram
# --------------------------------------------------------------------------------------------------------

# initialize

import numpy as np
import pandas as pd
#import glob
import os
import matplotlib.pyplot as plt

#from datetime import datetime, date 
import re # regular expression
#import warnings
import seaborn as sns

# %matplotlib inline
# %matplotlib notebook

PATH_DATA = r'../../data/'
INTERACTIVE = False
VALUE_COLNAME = 'nImmigrants'  # name for new column containing value of timeseries

if INTERACTIVE:
    # %matplotlib notebook
else:
    # %matplotlib inline

# %% [markdown]
# ## Immigration
#
# _Total number of long-term immigrants arriving into the reporting country during the reference year._
#
# - information about data availabilty
# https://ec.europa.eu/eurostat/web/main/data/database?p_p_id=NavTreeportletprod_WAR_NavTreeportletprod_INSTANCE_nPqeVbPXRmWQ&p_p_lifecycle=0&p_p_state=pop_up&p_p_mode=view&_NavTreeportletprod_WAR_NavTreeportletprod_INSTANCE_nPqeVbPXRmWQ_nodeInfoService=true&nodeId=-9012
#
# - meta data: N/A
# Last data update: 	27/04/2021  23:00 (8 months ago)
# Overall data coverage: 	2008 — 2019
# Source data set: https://ec.europa.eu/eurostat/databrowser/product/view/MIGR_IMM1CTZ
#
# for each EU country (35), #immigrants for 2008-2019
# special cases: ":" missing;
# two sets: agedef = COMPLET (age in completed years) and REACH (age reached during the year), resp.
#
# Missing values are indicated by a colon.
# Numbers may be accompanied by a 1- or 2-letter code with the following meaning:
#
# - b: break in time series
# - bp: break in time series, provisional
# - p: provisional
# - e: estimated
# - ep: estimated, provisional
#
# For the purpose of this study, this information is ignored and hence the characters removed, facilitating conversion of the data to numeric.
# - NO languages, no source country

# %%
fileName = PATH_DATA + 'tps00176.tsv'
# header = 1st line; missing value indicated by colon (followed by a space)
immigrationData = pd.read_csv(fileName, sep='\t', na_values=[': '], header=0)

# %%
immigrationData
# Out:
#    citizen,agedef,age,unit,sex,geo\time     2008     2009      2010   \
# 0           TOTAL,COMPLET,TOTAL,NR,T,AT    73772    69295     70978
# 1           TOTAL,COMPLET,TOTAL,NR,T,BE       NaN      NaN  135281 b
# 2           TOTAL,COMPLET,TOTAL,NR,T,BG       NaN      NaN       NaN
# 3           TOTAL,COMPLET,TOTAL,NR,T,CH   184297   160623    161778
# 4           TOTAL,COMPLET,TOTAL,NR,T,CY    21060   22581 b    20206
# ..                                  ...       ...      ...       ...
# 63            TOTAL,REACH,TOTAL,NR,T,RO  138929 b  135844    149885
# 64            TOTAL,REACH,TOTAL,NR,T,SE   101171   102280     98801
# 65            TOTAL,REACH,TOTAL,NR,T,SI   30693 b   30296     15416
# 66            TOTAL,REACH,TOTAL,NR,T,SK     8765     6346      5272
# 67            TOTAL,REACH,TOTAL,NR,T,UK  590242 b  566514    590950
#
#        2011      2012     2013     2014      2015     2016      2017   \
# 0     82230     91557   101866   116262    166323   129509    111801
# 1   147377 b   129477   120078   123158    146626   123702    126703
# 2        NaN  14103 bp  18570 p  26615 p   25223 p   21241    25597 p
# 3   148799 b   149051   160157   156282    153627   149305    143377
# 4     23037     17476    13149     9212     15183    17391     21306
# ..       ...       ...      ...      ...       ...      ...       ...
# 63   147685    167266   153646   136035   132795 e  137455   177435 e
# 64    96467    103059   115845   126966    134240   163005    144489
# 65    14083     15022    13871    13846     15420    16623     18808
# 66     4829     5419 p   5149 p   5357 p    6997 p   7686 p    7188 p
# 67   566044    498040   526046   631991    631452   588993    644209
#
#        2018      2019
# 0    105633    109167
# 1    137860    150006
# 2    29559 p   37929 p
# 3    144857    145129
# 4     23442     26170
# ..       ...       ...
# 63  172578 e  202422 e
# 64   132602    115805
# 65    28455     31319
# 66    7253 p    7016 p
# 67  603953 p   680906
#
# [68 rows x 13 columns]

# %% [markdown]
# First column defines content of time series.
# There are two sets: agedef = COMPLET (age in completed years) and REACH (age reached during the year), resp.
# In each group, there is a row for each country of the European Union (last two letters of 1st column).
# Since age is no criterion, the two sets are equal and only the first half of the dat is considered.

# %%
# remove duplicates and transform first column (keep only country code)

keepNRows = immigrationData.shape[0] // 2 # keep first half of table (68 -> 34)
immigrationData = immigrationData.iloc[0:keepNRows, ]

# keep last two characters (country code) -> new first column 'country'
immigrationData.insert(0, 'country', immigrationData.iloc[ : , 0].apply(lambda s: s[-2: ])) 
immigrationData
# Out:
#    country citizen,agedef,age,unit,sex,geo\time     2008      2009      2010   \
# 0       AT          TOTAL,COMPLET,TOTAL,NR,T,AT    73772     69295     70978
# 1       BE          TOTAL,COMPLET,TOTAL,NR,T,BE       NaN       NaN  135281 b
# 2       BG          TOTAL,COMPLET,TOTAL,NR,T,BG       NaN       NaN       NaN
# 3       CH          TOTAL,COMPLET,TOTAL,NR,T,CH   184297    160623    161778
# 4       CY          TOTAL,COMPLET,TOTAL,NR,T,CY    21060    22581 b    20206
# 5       CZ          TOTAL,COMPLET,TOTAL,NR,T,CZ  108267 b    75620     48317
# 6       DE          TOTAL,COMPLET,TOTAL,NR,T,DE   682146   346216 b   404055
# 7       DK          TOTAL,COMPLET,TOTAL,NR,T,DK   57357 b    51800     52236
# 8       EE          TOTAL,COMPLET,TOTAL,NR,T,EE     3671      3884      2810
# 9       EL          TOTAL,COMPLET,TOTAL,NR,T,EL    66529     58613     60462
# 10      ES          TOTAL,COMPLET,TOTAL,NR,T,ES  599075 b   392962    360705
# 11      FI          TOTAL,COMPLET,TOTAL,NR,T,FI    29114     26699     25636
# 12      FR          TOTAL,COMPLET,TOTAL,NR,T,FR   296608    296970   307111 b
# 13      HR          TOTAL,COMPLET,TOTAL,NR,T,HR   16883 b    13213      8846
# 14      HU          TOTAL,COMPLET,TOTAL,NR,T,HU   37652 b    27894    25519 b
# 15      IE          TOTAL,COMPLET,TOTAL,NR,T,IE    82592     50604     52339
# 16      IS          TOTAL,COMPLET,TOTAL,NR,T,IS    10288     3921 b     3948
# 17      IT          TOTAL,COMPLET,TOTAL,NR,T,IT   534712    442940    458856
# 18      LI          TOTAL,COMPLET,TOTAL,NR,T,LI     578 b      584       591
# 19      LT          TOTAL,COMPLET,TOTAL,NR,T,LT     9297      6487      5213
# 20      LU          TOTAL,COMPLET,TOTAL,NR,T,LU    17758     15751     16962
# 21      LV          TOTAL,COMPLET,TOTAL,NR,T,LV     4678      3731      4011
# 22      ME          TOTAL,COMPLET,TOTAL,NR,T,ME       NaN       NaN     5749
# 23      MK          TOTAL,COMPLET,TOTAL,NR,T,MK     1052       857      1359
# 24      MT          TOTAL,COMPLET,TOTAL,NR,T,MT     6043      6161      4275
# 25      NL          TOTAL,COMPLET,TOTAL,NR,T,NL   143516   122917 b   126776
# 26      NO          TOTAL,COMPLET,TOTAL,NR,T,NO   58123 b    55953     69214
# 27      PL          TOTAL,COMPLET,TOTAL,NR,T,PL    15275   189166 b   155131
# 28      PT          TOTAL,COMPLET,TOTAL,NR,T,PT    29718     32307     27575
# 29      RO          TOTAL,COMPLET,TOTAL,NR,T,RO  138929 b   135844    149885
# 30      SE          TOTAL,COMPLET,TOTAL,NR,T,SE   101171    102280     98801
# 31      SI          TOTAL,COMPLET,TOTAL,NR,T,SI   30693 b    30296     15416
# 32      SK          TOTAL,COMPLET,TOTAL,NR,T,SK     8765      6346      5272
# 33      UK          TOTAL,COMPLET,TOTAL,NR,T,UK  590242 b   566514    590950
#
#        2011      2012     2013      2014       2015       2016       2017   \
# 0     82230     91557   101866    116262     166323     129509     111801
# 1   147377 b   129477   120078    123158     146626     123702     126703
# 2        NaN  14103 bp  18570 p   26615 p    25223 p     21241     25597 p
# 3   148799 b   149051   160157    156282     153627     149305     143377
# 4     23037     17476    13149      9212      15183      17391      21306
# 5    27114 b    34337   30124 b    29897      29602      64083      51847
# 6    489422    592175   692713   884893 e  1571047 e  1029852 b  917109 be
# 7     52833     54409    60312     68388      78492      74383      68579
# 8      3709      2639     4109      3904     15413 b     14822      17616
# 9    60089 b    58200    57946     59013     64446 b   116867 b    112247
# 10   371331    304053   280772    305454     342114     414746     532132
# 11    29481     31278    31941     31507      28746      34905      31797
# 12   319816    327431   338752    340383     364221     377709     369621
# 13     8534      8959    10378     10638      11706      13985      15553
# 14    28018     33702    38968     54581      58344      53618      68070
# 15   57292 b    61324    65539     73519      80792      85185      78499
# 16     4073      4960     6406      5368       5635       8710      12116
# 17   385793    350772   307454    277631     280078     300823     343440
# 18      650       671      696       615        657        607        645
# 19    15685     19843    22011     24294      22130      20162      20368
# 20    20268     20478    21098     22332      23803      22888      24379
# 21    10234     13303     8299     10365       9479       8345       9916
# 22     6025      5727     5112      5353       4553       4904       6684
# 23     1464      1715     2050      1935       1741       2262       2064
# 24     5465      8256    10897     14454      16936      17051      21676
# 25   130118    124566   129428    145323     166872     189232     189646
# 26    70337     69908    68313     66903      60816      61460      53351
# 27   157059    217546   220311   222275 p   218147 p  208302 ep  209353 ep
# 28    19667     14606    17554     19516     29896 e    29925 e    36639 e
# 29   147685    167266   153646    136035    132795 e    137455    177435 e
# 30    96467    103059   115845    126966     134240     163005     144489
# 31    14083     15022    13871     13846      15420      16623      18808
# 32     4829     5419 p   5149 p    5357 p     6997 p     7686 p     7188 p
# 33   566044    498040   526046    631991     631452     588993     644209
#
#         2018       2019
# 0     105633     109167
# 1     137860     150006
# 2     29559 p    37929 p
# 3     144857     145129
# 4      23442      26170
# 5      65910     105888
# 6   893886 be  886341 be
# 7      64669      61384
# 8      17547      18259
# 9     119489     129459
# 10    643684     750480
# 11     31106      32758
# 12    387158     385591
# 13     26029      37726
# 14     82937      88581
# 15     97712      85630
# 16     11830       9872
# 17    332324     332778
# 18       649        727
# 19     28914      40067
# 20     24644      26668
# 21     10909      11223
# 22      8643      10737
# 23      2053       2118
# 24     26444      28341
# 25    194306     215756
# 26     47864      48680
# 27  214083 ep  226649 ep
# 28     43170      72725
# 29   172578 e   202422 e
# 30    132602     115805
# 31     28455      31319
# 32     7253 p     7016 p
# 33   603953 p    680906

# %%
# drop second column
colName = immigrationData.columns[1] 
immigrationData.pop(colName)
immigrationData
# Out:
#    country     2008      2009      2010      2011      2012     2013   \
# 0       AT    73772     69295     70978     82230     91557   101866
# 1       BE       NaN       NaN  135281 b  147377 b   129477   120078
# 2       BG       NaN       NaN       NaN       NaN  14103 bp  18570 p
# 3       CH   184297    160623    161778   148799 b   149051   160157
# 4       CY    21060    22581 b    20206     23037     17476    13149
# 5       CZ  108267 b    75620     48317    27114 b    34337   30124 b
# 6       DE   682146   346216 b   404055    489422    592175   692713
# 7       DK   57357 b    51800     52236     52833     54409    60312
# 8       EE     3671      3884      2810      3709      2639     4109
# 9       EL    66529     58613     60462    60089 b    58200    57946
# 10      ES  599075 b   392962    360705    371331    304053   280772
# 11      FI    29114     26699     25636     29481     31278    31941
# 12      FR   296608    296970   307111 b   319816    327431   338752
# 13      HR   16883 b    13213      8846      8534      8959    10378
# 14      HU   37652 b    27894    25519 b    28018     33702    38968
# 15      IE    82592     50604     52339    57292 b    61324    65539
# 16      IS    10288     3921 b     3948      4073      4960     6406
# 17      IT   534712    442940    458856    385793    350772   307454
# 18      LI     578 b      584       591       650       671      696
# 19      LT     9297      6487      5213     15685     19843    22011
# 20      LU    17758     15751     16962     20268     20478    21098
# 21      LV     4678      3731      4011     10234     13303     8299
# 22      ME       NaN       NaN     5749      6025      5727     5112
# 23      MK     1052       857      1359      1464      1715     2050
# 24      MT     6043      6161      4275      5465      8256    10897
# 25      NL   143516   122917 b   126776    130118    124566   129428
# 26      NO   58123 b    55953     69214     70337     69908    68313
# 27      PL    15275   189166 b   155131    157059    217546   220311
# 28      PT    29718     32307     27575     19667     14606    17554
# 29      RO  138929 b   135844    149885    147685    167266   153646
# 30      SE   101171    102280     98801     96467    103059   115845
# 31      SI   30693 b    30296     15416     14083     15022    13871
# 32      SK     8765      6346      5272      4829     5419 p   5149 p
# 33      UK  590242 b   566514    590950    566044    498040   526046
#
#        2014       2015       2016       2017       2018       2019
# 0    116262     166323     129509     111801     105633     109167
# 1    123158     146626     123702     126703     137860     150006
# 2    26615 p    25223 p     21241     25597 p    29559 p    37929 p
# 3    156282     153627     149305     143377     144857     145129
# 4      9212      15183      17391      21306      23442      26170
# 5     29897      29602      64083      51847      65910     105888
# 6   884893 e  1571047 e  1029852 b  917109 be  893886 be  886341 be
# 7     68388      78492      74383      68579      64669      61384
# 8      3904     15413 b     14822      17616      17547      18259
# 9     59013     64446 b   116867 b    112247     119489     129459
# 10   305454     342114     414746     532132     643684     750480
# 11    31507      28746      34905      31797      31106      32758
# 12   340383     364221     377709     369621     387158     385591
# 13    10638      11706      13985      15553      26029      37726
# 14    54581      58344      53618      68070      82937      88581
# 15    73519      80792      85185      78499      97712      85630
# 16     5368       5635       8710      12116      11830       9872
# 17   277631     280078     300823     343440     332324     332778
# 18      615        657        607        645        649        727
# 19    24294      22130      20162      20368      28914      40067
# 20    22332      23803      22888      24379      24644      26668
# 21    10365       9479       8345       9916      10909      11223
# 22     5353       4553       4904       6684       8643      10737
# 23     1935       1741       2262       2064       2053       2118
# 24    14454      16936      17051      21676      26444      28341
# 25   145323     166872     189232     189646     194306     215756
# 26    66903      60816      61460      53351      47864      48680
# 27  222275 p   218147 p  208302 ep  209353 ep  214083 ep  226649 ep
# 28    19516     29896 e    29925 e    36639 e     43170      72725
# 29   136035    132795 e    137455    177435 e   172578 e   202422 e
# 30   126966     134240     163005     144489     132602     115805
# 31    13846      15420      16623      18808      28455      31319
# 32    5357 p     6997 p     7686 p     7188 p     7253 p     7016 p
# 33   631991     631452     588993     644209    603953 p    680906

# %%
# convert year column names to integer 
yearColumns = range(2008,2020) 
newColumnNames = list(["country", *yearColumns])  # "*" unpacks range
immigrationData.columns = newColumnNames
# immigrationData.columns.values 
# immigrationData["country"]
immigrationData[yearColumns]
# Out:
#         2008      2009      2010      2011      2012     2013      2014  \
# 0     73772     69295     70978     82230     91557   101866    116262
# 1        NaN       NaN  135281 b  147377 b   129477   120078    123158
# 2        NaN       NaN       NaN       NaN  14103 bp  18570 p   26615 p
# 3    184297    160623    161778   148799 b   149051   160157    156282
# 4     21060    22581 b    20206     23037     17476    13149      9212
# 5   108267 b    75620     48317    27114 b    34337   30124 b    29897
# 6    682146   346216 b   404055    489422    592175   692713   884893 e
# 7    57357 b    51800     52236     52833     54409    60312     68388
# 8      3671      3884      2810      3709      2639     4109      3904
# 9     66529     58613     60462    60089 b    58200    57946     59013
# 10  599075 b   392962    360705    371331    304053   280772    305454
# 11    29114     26699     25636     29481     31278    31941     31507
# 12   296608    296970   307111 b   319816    327431   338752    340383
# 13   16883 b    13213      8846      8534      8959    10378     10638
# 14   37652 b    27894    25519 b    28018     33702    38968     54581
# 15    82592     50604     52339    57292 b    61324    65539     73519
# 16    10288     3921 b     3948      4073      4960     6406      5368
# 17   534712    442940    458856    385793    350772   307454    277631
# 18     578 b      584       591       650       671      696       615
# 19     9297      6487      5213     15685     19843    22011     24294
# 20    17758     15751     16962     20268     20478    21098     22332
# 21     4678      3731      4011     10234     13303     8299     10365
# 22       NaN       NaN     5749      6025      5727     5112      5353
# 23     1052       857      1359      1464      1715     2050      1935
# 24     6043      6161      4275      5465      8256    10897     14454
# 25   143516   122917 b   126776    130118    124566   129428    145323
# 26   58123 b    55953     69214     70337     69908    68313     66903
# 27    15275   189166 b   155131    157059    217546   220311   222275 p
# 28    29718     32307     27575     19667     14606    17554     19516
# 29  138929 b   135844    149885    147685    167266   153646    136035
# 30   101171    102280     98801     96467    103059   115845    126966
# 31   30693 b    30296     15416     14083     15022    13871     13846
# 32     8765      6346      5272      4829     5419 p   5149 p    5357 p
# 33  590242 b   566514    590950    566044    498040   526046    631991
#
#          2015       2016       2017       2018       2019
# 0     166323     129509     111801     105633     109167
# 1     146626     123702     126703     137860     150006
# 2     25223 p     21241     25597 p    29559 p    37929 p
# 3     153627     149305     143377     144857     145129
# 4      15183      17391      21306      23442      26170
# 5      29602      64083      51847      65910     105888
# 6   1571047 e  1029852 b  917109 be  893886 be  886341 be
# 7      78492      74383      68579      64669      61384
# 8     15413 b     14822      17616      17547      18259
# 9     64446 b   116867 b    112247     119489     129459
# 10    342114     414746     532132     643684     750480
# 11     28746      34905      31797      31106      32758
# 12    364221     377709     369621     387158     385591
# 13     11706      13985      15553      26029      37726
# 14     58344      53618      68070      82937      88581
# 15     80792      85185      78499      97712      85630
# 16      5635       8710      12116      11830       9872
# 17    280078     300823     343440     332324     332778
# 18       657        607        645        649        727
# 19     22130      20162      20368      28914      40067
# 20     23803      22888      24379      24644      26668
# 21      9479       8345       9916      10909      11223
# 22      4553       4904       6684       8643      10737
# 23      1741       2262       2064       2053       2118
# 24     16936      17051      21676      26444      28341
# 25    166872     189232     189646     194306     215756
# 26     60816      61460      53351      47864      48680
# 27   218147 p  208302 ep  209353 ep  214083 ep  226649 ep
# 28    29896 e    29925 e    36639 e     43170      72725
# 29   132795 e    137455    177435 e   172578 e   202422 e
# 30    134240     163005     144489     132602     115805
# 31     15420      16623      18808      28455      31319
# 32     6997 p     7686 p     7188 p     7253 p     7016 p
# 33    631452     588993     644209    603953 p    680906

# %% [markdown]
# Missing values are indicated by a colon.
# Numbers may be accompanied by a 1- or 2-letter code with the following meaning:
#
# - b: break in time series
# - bp: break in time series, provisional
# - p: provisional
# - e: estimated
# - ep: estimated, provisional
#
# For the purpose of this study, this information is ignored and hence the characters removed, facilitating conversion of the data to numeric.

# %%
# -- cleanse data
# immigrationData.replace("[a-z]+", "", regex=True, inplace=True) # warning (could be ignored)
immigrationData = immigrationData.replace("[a-z]+", "", regex=True, inplace=False) # alternative

# -- missing values
print("Count missing values per year:")
print(immigrationData.isna().sum())
# Out:
# Count missing values per year:
# country    0
# 2008       3
# 2009       3
# 2010       1
# 2011       1
# 2012       0
# 2013       0
# 2014       0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# 2019       0
# dtype: int64

# %%
immigrationData.dtypes # all object
# -> convert all year columns of DataFrame to numeric (and ignore errors caused by country)
immigrationData = immigrationData.apply(pd.to_numeric, errors='ignore')
# imputation: linear
immigrationDataImputed = immigrationData.interpolate(method = 'linear', limit_direction = 'both', axis = 0)

# %%
# year columns become attribute (pivoting wide to long -> melt())
# key is country (for each year and country, a row is to be created)
# use the year columns for the value column 
immigrationData = immigrationDataImputed.melt(['country'], value_vars = yearColumns, var_name = 'year', 
                                              value_name = VALUE_COLNAME)

# %%
# -- create an index
#immigrationData.set_index(['year', 'country'], inplace = True)
immigrationData.set_index(['year'], inplace = True)

# %%
# -- plot timeseries ----
sns.set()
diagTitle = "Total number of long-term immigrants arriving into the reporting country during the reference year"
# 1 plot per country:
# _ = immigrationData.groupby('country').plot(figsize = [14,20]) 
# all countries in 1 plot:
ax = immigrationData.groupby('country')[VALUE_COLNAME].plot(figsize = [12,14], legend=True, title=diagTitle,
                        ylabel = 'Mio.') #yticks = range(0, 2000000, 500000)
                                #scilimits=None)
#ax.yaxis.get_major_formatter().set_scientific(False)

# %%
# alternative: 1 col/country
# _= immigrationData.pivot(columns='country', values=VALUE_COLNAME).plot(figsize = [12,14], title=diagTitle)

# %%
if False:
    immigrationData.reset_index(inplace=True)
    immigrationData

# %%
# save processed data
immigrationData.to_csv(os.path.join(PATH_DATA, "population", "immigrants.csv"), index=True)
