# %% [markdown]
# # Data Preparation

# %%
# --------------------------------------------------------------------------------------------------------
# ciaFactBook.ipynb -- data preparation, inspection, and visualization 
# --------------------------------------------------------------------------------------------------------
# 0.01|03.01.22|AB|creation
# 0.02|16.01.22|AB|filter Europe, cleanse data, save as csv
# 0.03|18.01.22|AB|join with other tables, enhancements
# --------------------------------------------------------------------------------------------------------

# initialize

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

#from datetime import datetime, date 
import re # regular expression
import seaborn as sns

PATH_DATA = r'../../data/'
INTERACTIVE = False
VALUE_COLNAME = 'language'  # name for new column containing value

if INTERACTIVE:
    # %matplotlib notebook
else:
    # %matplotlib inline

# %% [markdown]
# ## Languages per country (official, minority)
#
# _The number of persons having their usual residence in a country on 1 January of the respective year. When usually resident population is not available, countries may report legal or registered residents._
#
# https://www.cia.gov/the-world-factbook/about/archives/

# %%
fileName = PATH_DATA + 'countries_languages_all.csv'
# header = 1st line
data = pd.read_csv(fileName, sep=',', header=0)

# %%
data.head()
# Out:
#        Country                               Recognized Languages
# 0  Afghanistan  Afghan Persian or Dari (official) 77% (Dari fu...
# 1      Albania  Albanian 98.8% (official - derived from Tosk d...
# 2      Algeria  Arabic (official), French (lingua franca), Ber...
# 3      Andorra  Catalan (official), French, Castilian, Portuguese
# 4       Angola  Portuguese 71.2% (official), Umbundu 23%, Kiko...

# %% [markdown]
# Non-European countries to be  filtered out.
# Second (unstructured) column is transformed as follows:
# - Split text into 1 column per language
# - add one column for share / official (yes/no)

# %%
# data['Recognized Languages'].str.extract([A-Z][a-z]+ )
# split column into column per language
data = data.join(data['Recognized Languages'].str.split(',', expand=True))

# %%
# drop split column
data.pop('Recognized Languages')
data.head()
# Out:
#        Country                                                  0  \
# 0  Afghanistan  Afghan Persian or Dari (official) 77% (Dari fu...
# 1      Albania  Albanian 98.8% (official - derived from Tosk d...
# 2      Algeria                                  Arabic (official)
# 3      Andorra                                 Catalan (official)
# 4       Angola                        Portuguese 71.2% (official)
#
#                          1                                                  2  \
# 0    Pashto (official) 48%                                          Uzbek 11%
# 1               Greek 0.5%                   other 0.6% (including Macedonian
# 2   French (lingua franca)   Berber or Tamazight (official); dialects incl...
# 3                   French                                          Castilian
# 4              Umbundu 23%                                       Kikongo 8.2%
#
#                            3             4                         5  \
# 0                 English 6%    Turkmen 3%                   Urdu 3%
# 1                     Romani         Vlach                   Turkish
# 2   Shawiya Berber (Tacawit)   Mzab Berber   Tuareg Berber (Tamahaq)
# 3                 Portuguese          None                      None
# 4              Kimbundu 7.8%   Chokwe 6.5%              Nhaneca 3.4%
#
#                  6                     7                              8  \
# 0       Pashayi 1%          Nuristani 1%                      Arabic 1%
# 1          Italian   and Serbo-Croatian)   unspecified 0.1% (2011 est.)
# 2             None                  None                           None
# 3             None                  None                           None
# 4   Nganguela 3.1%            Fiote 2.4%                  Kwanhama 2.3%
#
#                          9          10                       11    12    13  \
# 0   Balochi 1% (2017 est.)        None                     None  None  None
# 1                     None        None                     None  None  None
# 2                     None        None                     None  None  None
# 3                     None        None                     None  None  None
# 4             Muhumbi 2.1%   Luvale 1%   other 3.6% (2014 est.)  None  None
#
#      14    15    16    17    18
# 0  None  None  None  None  None
# 1  None  None  None  None  None
# 2  None  None  None  None  None
# 3  None  None  None  None  None
# 4  None  None  None  None  None

# %%
# create a row for each country-language combination (pivot wide -> long)
# key is country (for each language and country, a row is to be created)
#data = 
data = data.melt(['Country'], value_name = 'languageRaw', var_name = 'langId')
#, var_name = 'langId', value_vars = None, value_name = None)   #, value_name = VALUE_COLNAME)
# remove empty languages
data = data.dropna()
# note: the number of languages spoken in a given country is equal to max(langId)+1; 
# most languages are spoken in Zambia (18)
data.head()
# Out:
#        Country langId                                        languageRaw
# 0  Afghanistan      0  Afghan Persian or Dari (official) 77% (Dari fu...
# 1      Albania      0  Albanian 98.8% (official - derived from Tosk d...
# 2      Algeria      0                                  Arabic (official)
# 3      Andorra      0                                 Catalan (official)
# 4       Angola      0                        Portuguese 71.2% (official)

# %%
# European languages only
# join with european_languages.csv
eur_lang = pd.read_csv("../../data/general/european_languages.csv")
eur_lang.head()
# Out:
#   LangID CountryID LangStatus            Name_lang Name_country    Area
# 0    aae        IT          L  Albanian, Arbëreshë        Italy  Europe
# 1    cim        IT          L             Cimbrian        Italy  Europe
# 2    egl        IT          L              Emilian        Italy  Europe
# 3    fur        IT          L             Friulian        Italy  Europe
# 4    ils        IT          L   International Sign        Italy  Europe

# %%
# semi join with European languages
data = data[data.Country.isin(eur_lang.Name_country)]
data.head()
# Out:
#                    Country langId  \
# 1                  Albania      0
# 9                  Austria      0
# 15                 Belarus      0
# 16                 Belgium      0
# 21  Bosnia and Herzegovina      0
#
#                                           languageRaw
# 1   Albanian 98.8% (official - derived from Tosk d...
# 9                  German (official nationwide) 88.6%
# 15                           Russian (official) 70.2%
# 16                               Dutch (official) 60%
# 21                           Bosnian (official) 52.9%

# %%
# -- create an index
data.set_index(['Country', 'langId'], inplace = True)

# %%
# mark official languages (new column official [Boolean])
pattern = "official"  
# data[data['languageRaw'].str.contains(pattern)]
data['official'] = data['languageRaw'].str.contains(pattern)
data
# Out:
#                                                                      languageRaw  \
# Country                langId
# Albania                0       Albanian 98.8% (official - derived from Tosk d...
# Austria                0                      German (official nationwide) 88.6%
# Belarus                0                                Russian (official) 70.2%
# Belgium                0                                    Dutch (official) 60%
# Bosnia and Herzegovina 0                                Bosnian (official) 52.9%
# ...                                                                          ...
# Luxembourg             8                                  other 8.4% (2011 est.)
# Spain                  8                                           000 speakers)
# Switzerland            8                                 Romansh (official) 0.5%
# France                 9                                                 Picard)
# Switzerland            9                                  other 7.7% (2017 est.)
#
#                                official
# Country                langId
# Albania                0           True
# Austria                0           True
# Belarus                0           True
# Belgium                0           True
# Bosnia and Herzegovina 0           True
# ...                                 ...
# Luxembourg             8          False
# Spain                  8          False
# Switzerland            8           True
# France                 9          False
# Switzerland            9          False
#
# [186 rows x 2 columns]

# %%
# Extract actual language name, identified as the first capitalized word (this heuristic introduces some NA's)
pattern = r'(?P<language>[A-Z][a-z]+)'  # named group becomes new column 'language'
#data['languageRaw'].str.extract(pattern)
data = data.join(data['languageRaw'].str.extract(pattern))
data = data.dropna()
data.sort_values(by = ["Country", "langId"], inplace=True)

# %%
# data cleansing
data.drop(("Austria", 5), axis=0, inplace = True)
data.drop(("Ireland", 3), axis=0, inplace = True)
data.drop(("Ireland", 4), axis=0, inplace = True)
data.loc["United Kingdom", "official"] = True
data.loc[("Albania", 7), "language"] = "Croatian"
data.loc[("Austria", 7), "language"] = "Burgenland Croatian"
data
# Out:
#                                                              languageRaw  \
# Country        langId
# Albania        0       Albanian 98.8% (official - derived from Tosk d...
#                1                                              Greek 0.5%
#                2                        other 0.6% (including Macedonian
#                3                                                  Romani
#                4                                                   Vlach
# ...                                                                  ...
# Ukraine        1                       Russian (regional language) 29.6%
#                2                    other (includes small Crimean Tatar-
#                3                                      Moldovan/Romanian-
#                4        and Hungarian-speaking minorities) 2.9% (2001...
# United Kingdom 0                                                 English
#
#                        official    language
# Country        langId
# Albania        0           True    Albanian
#                1          False       Greek
#                2          False  Macedonian
#                3          False      Romani
#                4          False       Vlach
# ...                         ...         ...
# Ukraine        1          False     Russian
#                2          False     Crimean
#                3          False    Moldovan
#                4          False   Hungarian
# United Kingdom 0           True     English
#
# [148 rows x 3 columns]

# %%
# save processed data
data.to_csv(os.path.join(PATH_DATA, "general", "countries_languages_eur.csv"), index=True)

# %%
# get endangerment status
endangered = pd.read_csv("../../data/endangerment/endangered_languages_europe.csv")

# %%
# join with endangered_languages_europe.csv
endangered = endangered[["Name in English", "Degree of endangerment","Endangerment code", "Number of speakers"]]
endangered.head()
# Out:
#   Name in English Degree of endangerment  Endangerment code  \
# 0   South Italian             Vulnerable                  1
# 1        Sicilian             Vulnerable                  1
# 2       Low Saxon             Vulnerable                  1
# 3      Belarusian             Vulnerable                  1
# 4         Lombard  Definitely endangered                  2
#
#    Number of speakers
# 0           7500000.0
# 1           5000000.0
# 2           4800000.0
# 3           4000000.0
# 4           3500000.0

# %%
# keep index -> back to columns
data.reset_index(inplace=True)
dataEndangered = pd.merge(data, endangered, how='left', left_on=['language'], right_on=["Name in English"])
#data #.head()

# %%
dataEndangered
# Out:
#             Country  langId  \
# 0           Albania       0
# 1           Albania       1
# 2           Albania       2
# 3           Albania       3
# 4           Albania       4
# ..              ...     ...
# 143         Ukraine       1
# 144         Ukraine       2
# 145         Ukraine       3
# 146         Ukraine       4
# 147  United Kingdom       0
#
#                                            languageRaw  official    language  \
# 0    Albanian 98.8% (official - derived from Tosk d...      True    Albanian
# 1                                           Greek 0.5%     False       Greek
# 2                     other 0.6% (including Macedonian     False  Macedonian
# 3                                               Romani     False      Romani
# 4                                                Vlach     False       Vlach
# ..                                                 ...       ...         ...
# 143                  Russian (regional language) 29.6%     False     Russian
# 144               other (includes small Crimean Tatar-     False     Crimean
# 145                                 Moldovan/Romanian-     False    Moldovan
# 146   and Hungarian-speaking minorities) 2.9% (2001...     False   Hungarian
# 147                                            English      True     English
#
#     Name in English Degree of endangerment  Endangerment code  \
# 0               NaN                    NaN                NaN
# 1               NaN                    NaN                NaN
# 2               NaN                    NaN                NaN
# 3            Romani  Definitely endangered                2.0
# 4               NaN                    NaN                NaN
# ..              ...                    ...                ...
# 143             NaN                    NaN                NaN
# 144             NaN                    NaN                NaN
# 145             NaN                    NaN                NaN
# 146             NaN                    NaN                NaN
# 147             NaN                    NaN                NaN
#
#      Number of speakers
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3             3500000.0
# 4                   NaN
# ..                  ...
# 143                 NaN
# 144                 NaN
# 145                 NaN
# 146                 NaN
# 147                 NaN
#
# [148 rows x 9 columns]

# %%
# define class: Endangerment code NaN -> 0 (not endangered), integer -> 1 (endangered)
dataEndangered['endangered'] = [0 if pd.isna(ec) else 1 for ec in dataEndangered['Endangerment code']]
dataEndangered
# Out:
#             Country  langId  \
# 0           Albania       0
# 1           Albania       1
# 2           Albania       2
# 3           Albania       3
# 4           Albania       4
# ..              ...     ...
# 143         Ukraine       1
# 144         Ukraine       2
# 145         Ukraine       3
# 146         Ukraine       4
# 147  United Kingdom       0
#
#                                            languageRaw  official    language  \
# 0    Albanian 98.8% (official - derived from Tosk d...      True    Albanian
# 1                                           Greek 0.5%     False       Greek
# 2                     other 0.6% (including Macedonian     False  Macedonian
# 3                                               Romani     False      Romani
# 4                                                Vlach     False       Vlach
# ..                                                 ...       ...         ...
# 143                  Russian (regional language) 29.6%     False     Russian
# 144               other (includes small Crimean Tatar-     False     Crimean
# 145                                 Moldovan/Romanian-     False    Moldovan
# 146   and Hungarian-speaking minorities) 2.9% (2001...     False   Hungarian
# 147                                            English      True     English
#
#     Name in English Degree of endangerment  Endangerment code  \
# 0               NaN                    NaN                NaN
# 1               NaN                    NaN                NaN
# 2               NaN                    NaN                NaN
# 3            Romani  Definitely endangered                2.0
# 4               NaN                    NaN                NaN
# ..              ...                    ...                ...
# 143             NaN                    NaN                NaN
# 144             NaN                    NaN                NaN
# 145             NaN                    NaN                NaN
# 146             NaN                    NaN                NaN
# 147             NaN                    NaN                NaN
#
#      Number of speakers  endangered
# 0                   NaN           0
# 1                   NaN           0
# 2                   NaN           0
# 3             3500000.0           1
# 4                   NaN           0
# ..                  ...         ...
# 143                 NaN           0
# 144                 NaN           0
# 145                 NaN           0
# 146                 NaN           0
# 147                 NaN           0
#
# [148 rows x 10 columns]

# %%
# join with European languages for country code
eur_lang = eur_lang[["CountryID", "Name_country"]]
eur_lang = eur_lang.drop_duplicates()
eur_lang.head()
# Out:
#     CountryID        Name_country
# 0          IT               Italy
# 22         GR              Greece
# 31         RU  Russian Federation
# 124        NL         Netherlands
# 136        AL             Albania

# %%
dataLang = pd.merge(dataEndangered, eur_lang, how='left', left_on=['Country'], right_on=["Name_country"])
dataLang.head()
# Out:
#    Country  langId                                        languageRaw  \
# 0  Albania       0  Albanian 98.8% (official - derived from Tosk d...
# 1  Albania       1                                         Greek 0.5%
# 2  Albania       2                   other 0.6% (including Macedonian
# 3  Albania       3                                             Romani
# 4  Albania       4                                              Vlach
#
#    official    language Name in English Degree of endangerment  \
# 0      True    Albanian             NaN                    NaN
# 1     False       Greek             NaN                    NaN
# 2     False  Macedonian             NaN                    NaN
# 3     False      Romani          Romani  Definitely endangered
# 4     False       Vlach             NaN                    NaN
#
#    Endangerment code  Number of speakers  endangered CountryID Name_country
# 0                NaN                 NaN           0        AL      Albania
# 1                NaN                 NaN           0        AL      Albania
# 2                NaN                 NaN           0        AL      Albania
# 3                2.0           3500000.0           1        AL      Albania
# 4                NaN                 NaN           0        AL      Albania

# %%
dataLang.drop(columns =["Name_country"], inplace=True)

# %%
dataLang
# Out:
#             Country  langId  \
# 0           Albania       0
# 1           Albania       1
# 2           Albania       2
# 3           Albania       3
# 4           Albania       4
# ..              ...     ...
# 143         Ukraine       1
# 144         Ukraine       2
# 145         Ukraine       3
# 146         Ukraine       4
# 147  United Kingdom       0
#
#                                            languageRaw  official    language  \
# 0    Albanian 98.8% (official - derived from Tosk d...      True    Albanian
# 1                                           Greek 0.5%     False       Greek
# 2                     other 0.6% (including Macedonian     False  Macedonian
# 3                                               Romani     False      Romani
# 4                                                Vlach     False       Vlach
# ..                                                 ...       ...         ...
# 143                  Russian (regional language) 29.6%     False     Russian
# 144               other (includes small Crimean Tatar-     False     Crimean
# 145                                 Moldovan/Romanian-     False    Moldovan
# 146   and Hungarian-speaking minorities) 2.9% (2001...     False   Hungarian
# 147                                            English      True     English
#
#     Name in English Degree of endangerment  Endangerment code  \
# 0               NaN                    NaN                NaN
# 1               NaN                    NaN                NaN
# 2               NaN                    NaN                NaN
# 3            Romani  Definitely endangered                2.0
# 4               NaN                    NaN                NaN
# ..              ...                    ...                ...
# 143             NaN                    NaN                NaN
# 144             NaN                    NaN                NaN
# 145             NaN                    NaN                NaN
# 146             NaN                    NaN                NaN
# 147             NaN                    NaN                NaN
#
#      Number of speakers  endangered CountryID
# 0                   NaN           0        AL
# 1                   NaN           0        AL
# 2                   NaN           0        AL
# 3             3500000.0           1        AL
# 4                   NaN           0        AL
# ..                  ...         ...       ...
# 143                 NaN           0        UA
# 144                 NaN           0        UA
# 145                 NaN           0        UA
# 146                 NaN           0        UA
# 147                 NaN           0        GB
#
# [148 rows x 11 columns]

# %%
# NEXT: join with population, immigrants, emigrants where year = first and last (or take mean/median?!)

# %%
# save joined tables
dataLang.to_csv(os.path.join(PATH_DATA, "general", "flat_table.csv"), index=True)
