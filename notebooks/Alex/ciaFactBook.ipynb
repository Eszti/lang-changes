# %% [markdown]
# # Data Preparation

# %%
# --------------------------------------------------------------------------------------------------------
# ciaFactBook.ipynb -- data preparation, inspection, and visualization 
# --------------------------------------------------------------------------------------------------------
# 0.01|03.01.22|AB|creation
# 0.02|16.01.22|AB|filter Europe, cleanse data, save as csv
# --------------------------------------------------------------------------------------------------------

# initialize

import numpy as np
import pandas as pd
#import glob
#import os
import matplotlib.pyplot as plt

#from datetime import datetime, date 
import re # regular expression
import os
import seaborn as sns

# %matplotlib inline
# %matplotlib notebook

PATH_DATA = r'../../data/'
INTERACTIVE = False
VALUE_COLNAME = 'language'  # name for new column containing value

if INTERACTIVE:
    # %matplotlib notebook
else:
    # %matplotlib inline

# %% [markdown]
# ## Languages per country (official, minority)
#
# _The number of persons having their usual residence in a country on 1 January of the respective year. When usually resident population is not available, countries may report legal or registered residents._
#
# https://www.cia.gov/the-world-factbook/about/archives/

# %%
fileName = PATH_DATA + 'countries_languages_all.csv'
# header = 1st line
data = pd.read_csv(fileName, sep=',', header=0)

# %%
data
# Out:
#                              Country  \
# 0                        Afghanistan
# 1                            Albania
# 2                            Algeria
# 3                            Andorra
# 4                             Angola
# ..                               ...
# 209                          Vietnam
# 210  Western Sahara (proposed state)
# 211                            Yemen
# 212                           Zambia
# 213                         Zimbabwe
#
#                                   Recognized Languages
# 0    Afghan Persian or Dari (official) 77% (Dari fu...
# 1    Albanian 98.8% (official - derived from Tosk d...
# 2    Arabic (official), French (lingua franca), Ber...
# 3    Catalan (official), French, Castilian, Portuguese
# 4    Portuguese 71.2% (official), Umbundu 23%, Kiko...
# ..                                                 ...
# 209  Vietnamese (official), English (increasingly f...
# 210  Standard Arabic, Hassaniya Arabic, Moroccan Ar...
# 211                                  Arabic (official)
# 212  Bemba 33.4%, Nyanja 14.7%, Tonga 11.4%, Lozi 5...
# 213  Shona (official; most widely spoken), Ndebele ...
#
# [214 rows x 2 columns]

# %% [markdown]
# Non-European countries to be  filtered out.
# Second (unstructured) column is transformed as follows:
# - Split text into 1 column per language
# - add one column for share / official (yes/no)

# %%
# data['Recognized Languages'].str.extract([A-Z][a-z]+ )

# https://stackoverflow.com/questions/14745022/how-to-split-a-dataframe-string-column-into-two-columns/21296915#21296915
data = data.join(data['Recognized Languages'].str.split(',', expand=True))

# %%
# drop split column
data.pop('Recognized Languages')
data
# Out:
#                              Country  \
# 0                        Afghanistan
# 1                            Albania
# 2                            Algeria
# 3                            Andorra
# 4                             Angola
# ..                               ...
# 209                          Vietnam
# 210  Western Sahara (proposed state)
# 211                            Yemen
# 212                           Zambia
# 213                         Zimbabwe
#
#                                                      0  \
# 0    Afghan Persian or Dari (official) 77% (Dari fu...
# 1    Albanian 98.8% (official - derived from Tosk d...
# 2                                    Arabic (official)
# 3                                   Catalan (official)
# 4                          Portuguese 71.2% (official)
# ..                                                 ...
# 209                              Vietnamese (official)
# 210                                    Standard Arabic
# 211                                  Arabic (official)
# 212                                        Bemba 33.4%
# 213               Shona (official; most widely spoken)
#
#                                                      1  \
# 0                                Pashto (official) 48%
# 1                                           Greek 0.5%
# 2                               French (lingua franca)
# 3                                               French
# 4                                          Umbundu 23%
# ..                                                 ...
# 209   English (increasingly favored as a second lan...
# 210                                   Hassaniya Arabic
# 211                                               None
# 212                                       Nyanja 14.7%
# 213                                  Ndebele (official
#
#                                                      2  \
# 0                                            Uzbek 11%
# 1                     other 0.6% (including Macedonian
# 2     Berber or Tamazight (official); dialects incl...
# 3                                            Castilian
# 4                                         Kikongo 8.2%
# ..                                                 ...
# 209                                        some French
# 210                                    Moroccan Arabic
# 211                                               None
# 212                                        Tonga 11.4%
# 213                         second most widely spoken)
#
#                                                      3  \
# 0                                           English 6%
# 1                                               Romani
# 2                             Shawiya Berber (Tacawit)
# 3                                           Portuguese
# 4                                        Kimbundu 7.8%
# ..                                                 ...
# 209                                            Chinese
# 210                                             Berber
# 211                                               None
# 212                                          Lozi 5.5%
# 213   English (official; traditionally used for off...
#
#                                                     4  \
# 0                                          Turkmen 3%
# 1                                               Vlach
# 2                                         Mzab Berber
# 3                                                None
# 4                                         Chokwe 6.5%
# ..                                                ...
# 209                                         and Khmer
# 210                                           Spanish
# 211                                              None
# 212                                        Chewa 4.5%
# 213   13 minority languages (official; includes Chewa
#
#                                                      5                6  \
# 0                                              Urdu 3%       Pashayi 1%
# 1                                              Turkish          Italian
# 2                              Tuareg Berber (Tamahaq)             None
# 3                                                 None             None
# 4                                         Nhaneca 3.4%   Nganguela 3.1%
# ..                                                 ...              ...
# 209   mountain area languages (Mon-Khmer and Malayo...             None
# 210                                             French             None
# 211                                               None             None
# 212                                        Nsenga 2.9%     Tumbuka 2.5%
# 213                                           Chibarwe          Kalanga
#
#                                7                              8  \
# 0                   Nuristani 1%                      Arabic 1%
# 1            and Serbo-Croatian)   unspecified 0.1% (2011 est.)
# 2                           None                           None
# 3                           None                           None
# 4                     Fiote 2.4%                  Kwanhama 2.3%
# ..                           ...                            ...
# 209                         None                           None
# 210                         None                           None
# 211                         None                           None
# 212   Lunda (North Western) 1.9%                    Kaonde 1.8%
# 213                       Koisan                         Nambya
#
#                            9           10                        11  \
# 0     Balochi 1% (2017 est.)         None                      None
# 1                       None         None                      None
# 2                       None         None                      None
# 3                       None         None                      None
# 4               Muhumbi 2.1%    Luvale 1%    other 3.6% (2014 est.)
# ..                       ...          ...                       ...
# 209                     None         None                      None
# 210                     None         None                      None
# 211                     None         None                      None
# 212                Lala 1.8%   Lamba 1.8%   English (official) 1.7%
# 213                     Ndau     Shangani             sign language
#
#                12            13              14           15           16  \
# 0            None          None            None         None         None
# 1            None          None            None         None         None
# 2            None          None            None         None         None
# 3            None          None            None         None         None
# 4            None          None            None         None         None
# ..            ...           ...             ...          ...          ...
# 209          None          None            None         None         None
# 210          None          None            None         None         None
# 211          None          None            None         None         None
# 212   Luvale 1.5%   Mambwe 1.3%   Namwanga 1.2%   Lenje 1.1%      Bisa 1%
# 213         Sotho         Tonga          Tswana        Venda   and Xhosa)
#
#               17                             18
# 0           None                           None
# 1           None                           None
# 2           None                           None
# 3           None                           None
# 4           None                           None
# ..           ...                            ...
# 209         None                           None
# 210         None                           None
# 211         None                           None
# 212   other 9.7%   unspecified 0.2% (2010 est.)
# 213         None                           None
#
# [214 rows x 20 columns]

# %%
# create a row for each country-language combination (pivot wide -> long)
# key is country (for each language and country, a row is to be created)
#data = 
data = data.melt(['Country'], value_name = 'languageRaw', var_name = 'langId')
#, var_name = 'langId', value_vars = None, value_name = None)   #, value_name = VALUE_COLNAME)
data
# Out:
#                               Country langId  \
# 0                         Afghanistan      0
# 1                             Albania      0
# 2                             Algeria      0
# 3                             Andorra      0
# 4                              Angola      0
# ...                               ...    ...
# 4061                          Vietnam     18
# 4062  Western Sahara (proposed state)     18
# 4063                            Yemen     18
# 4064                           Zambia     18
# 4065                         Zimbabwe     18
#
#                                             languageRaw
# 0     Afghan Persian or Dari (official) 77% (Dari fu...
# 1     Albanian 98.8% (official - derived from Tosk d...
# 2                                     Arabic (official)
# 3                                    Catalan (official)
# 4                           Portuguese 71.2% (official)
# ...                                                 ...
# 4061                                               None
# 4062                                               None
# 4063                                               None
# 4064                       unspecified 0.2% (2010 est.)
# 4065                                               None
#
# [4066 rows x 3 columns]

# %%
# remove empty languages
data = data.dropna()
data
# note: the number of languages spoken in a given country is equal to max(langId)+1; 
# most languages are spoken in Zambia (18)
# Out:
#           Country langId                                        languageRaw
# 0     Afghanistan      0  Afghan Persian or Dari (official) 77% (Dari fu...
# 1         Albania      0  Albanian 98.8% (official - derived from Tosk d...
# 2         Algeria      0                                  Arabic (official)
# 3         Andorra      0                                 Catalan (official)
# 4          Angola      0                        Portuguese 71.2% (official)
# ...           ...    ...                                                ...
# 3572       Panama     16                                          Japanese)
# 3636       Zambia     16                                            Bisa 1%
# 3637     Zimbabwe     16                                         and Xhosa)
# 3850       Zambia     17                                         other 9.7%
# 4064       Zambia     18                       unspecified 0.2% (2010 est.)
#
# [1092 rows x 3 columns]

# %%
# European languages only
# join with european_languages.csv
eur_lang = pd.read_csv("../../data/general/european_languages.csv")
eur_lang
# Out:
#     LangID CountryID LangStatus                Name_lang Name_country    Area
# 0      aae        IT          L      Albanian, Arbëreshë        Italy  Europe
# 1      cim        IT          L                 Cimbrian        Italy  Europe
# 2      egl        IT          L                  Emilian        Italy  Europe
# 3      fur        IT          L                 Friulian        Italy  Europe
# 4      ils        IT          L       International Sign        Italy  Europe
# ..     ...       ...        ...                      ...          ...     ...
# 288    vgt        BE          L    Flemish Sign Language      Belgium  Europe
# 289    vls        BE          L             West Flemish      Belgium  Europe
# 290    wln        BE          L                  Walloon      Belgium  Europe
# 291    slv        SI          L                  Slovene     Slovenia  Europe
# 292    ysl        SI          L  Slovenian Sign Language     Slovenia  Europe
#
# [293 rows x 6 columns]

# %%
# semi join with European languages
data = data[data.Country.isin(eur_lang.Name_country)]
data
# Out:
#                      Country langId  \
# 1                    Albania      0
# 9                    Austria      0
# 15                   Belarus      0
# 16                   Belgium      0
# 21    Bosnia and Herzegovina      0
# ...                      ...    ...
# 1821              Luxembourg      8
# 1889                   Spain      8
# 1894             Switzerland      8
# 1989                  France      9
# 2108             Switzerland      9
#
#                                             languageRaw
# 1     Albanian 98.8% (official - derived from Tosk d...
# 9                    German (official nationwide) 88.6%
# 15                             Russian (official) 70.2%
# 16                                 Dutch (official) 60%
# 21                             Bosnian (official) 52.9%
# ...                                                 ...
# 1821                             other 8.4% (2011 est.)
# 1889                                      000 speakers)
# 1894                            Romansh (official) 0.5%
# 1989                                            Picard)
# 2108                             other 7.7% (2017 est.)
#
# [186 rows x 3 columns]

# %%
# -- create an index
data.set_index(['Country', 'langId'], inplace = True)

# %%
# mark official languages (new column official [Boolean])
pattern = "official"  
# data[data['languageRaw'].str.contains(pattern)]
data['official'] = data['languageRaw'].str.contains(pattern)
data
# Out:
# <ipython-input-11-a969672b09c6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['official'] = data['languageRaw'].str.contains(pattern)
#                                                                      languageRaw  \
# Country                langId
# Albania                0       Albanian 98.8% (official - derived from Tosk d...
# Austria                0                      German (official nationwide) 88.6%
# Belarus                0                                Russian (official) 70.2%
# Belgium                0                                    Dutch (official) 60%
# Bosnia and Herzegovina 0                                Bosnian (official) 52.9%
# ...                                                                          ...
# Luxembourg             8                                  other 8.4% (2011 est.)
# Spain                  8                                           000 speakers)
# Switzerland            8                                 Romansh (official) 0.5%
# France                 9                                                 Picard)
# Switzerland            9                                  other 7.7% (2017 est.)
#
#                                official
# Country                langId
# Albania                0           True
# Austria                0           True
# Belarus                0           True
# Belgium                0           True
# Bosnia and Herzegovina 0           True
# ...                                 ...
# Luxembourg             8          False
# Spain                  8          False
# Switzerland            8           True
# France                 9          False
# Switzerland            9          False
#
# [186 rows x 2 columns]

# %%
# Extract actual language name, identified as the first capitalized word (this heuristic introduces some NA's)
pattern = r'(?P<language>[A-Z][a-z]+)'  # named group becomes new column 'language'
data['languageRaw'].str.extract(pattern)
# data = data[data[colName].str.fullmatch(pattern)]
# Out:
#                                language
# Country                langId
# Albania                0       Albanian
# Austria                0         German
# Belarus                0        Russian
# Belgium                0          Dutch
# Bosnia and Herzegovina 0        Bosnian
# ...                                 ...
# Luxembourg             8            NaN
# Spain                  8            NaN
# Switzerland            8        Romansh
# France                 9         Picard
# Switzerland            9            NaN
#
# [186 rows x 1 columns]

# %%
data = data.join(data['languageRaw'].str.extract(pattern))
data = data.dropna()

# %%
data.sort_values(by = ["Country", "langId"], inplace=True)

# %%
# data cleansing

data.drop(("Austria", 5), axis=0, inplace = True)
data.drop(("Ireland", 3), axis=0, inplace = True)
data.drop(("Ireland", 4), axis=0, inplace = True)
data.loc["United Kingdom", "official"] = True
data.loc[("Albania", 7), "language"] = "Croatian"
data
# Out:
#                                                              languageRaw  \
# Country        langId
# Albania        0       Albanian 98.8% (official - derived from Tosk d...
#                1                                              Greek 0.5%
#                2                        other 0.6% (including Macedonian
#                3                                                  Romani
#                4                                                   Vlach
# ...                                                                  ...
# Ukraine        1                       Russian (regional language) 29.6%
#                2                    other (includes small Crimean Tatar-
#                3                                      Moldovan/Romanian-
#                4        and Hungarian-speaking minorities) 2.9% (2001...
# United Kingdom 0                                                 English
#
#                        official    language
# Country        langId
# Albania        0           True    Albanian
#                1          False       Greek
#                2          False  Macedonian
#                3          False      Romani
#                4          False       Vlach
# ...                         ...         ...
# Ukraine        1          False     Russian
#                2          False     Crimean
#                3          False    Moldovan
#                4          False   Hungarian
# United Kingdom 0           True     English
#
# [148 rows x 3 columns]

# %%
# save processed data
data.to_csv(os.path.join(PATH_DATA, "general", "countries_languages_eur.csv"), index=True)
